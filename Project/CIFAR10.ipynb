# %% [markdown]
# # CIFAR10 딥러닝 모델

# %% [markdown]
# CIFAR10 데이터셋은 32x32 픽셀의 6,000개 컬러 이미지로 이루어져 있으며 데이터셋의 각 이미지는 10개의 클래스로 라벨링되어 있으며, 머신러닝 연구에 가장 널리 사용되고 있다.

# %% [markdown]
# ## 데이터 로드 및 전처리

# %% [markdown]
# CIFAR10 데이터셋을 로드하고, 훈련 데이터셋에서 20%를 검증 데이터셋으로 분리한다.
# 데이터셋은 keras.datasets에서 불러올 수 있는 CIFAR10 데이터 셋을 활용한다.
# 데이터셋 분리 작업에서는 sklearn 라이브러리의 train_test_split 함수를 활용한다.
# 훈련, 검증, 테스트 데이터와 레이블 종류가 몇개인지 출력한다.

# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

from tensorflow.keras import models, layers
from tensorflow.keras.datasets import cifar10

# %%
# 문제 3-1: cifar10 데이터셋을 로드하고, 훈련 데이터셋에서 20%를 검증 데이터셋으로 분리합니다.
(x_train_full, y_train_full), (x_test, y_test) = cifar10.load_data()
x_train, x_val, y_train, y_val = train_test_split(x_train_full, y_train_full, test_size=0.2)

# 훈련, 검증, 테스트 데이터와 레이블 종류가 몇개인지 출력합니다.
print("전체 학습 데이터: {} 레이블: {}".format(x_train_full.shape, y_train_full.shape))
print("학습 데이터: {} 레이블: {}".format(x_train.shape, y_train.shape))
print("검증 데이터: {} 레이블: {}".format(x_val.shape, y_val.shape))
print("테스트 데이터: {} 레이블: {}".format(x_test.shape, y_test.shape))
# Out:
# 전체 학습 데이터: (50000, 32, 32, 3) 레이블: (50000, 1)
# 학습 데이터: (40000, 32, 32, 3) 레이블: (40000, 1)
# 검증 데이터: (10000, 32, 32, 3) 레이블: (10000, 1)
# 테스트 데이터: (10000, 32, 32, 3) 레이블: (10000, 1)

# %% [markdown]
# class_name 변수를 만들어 cifar10의 분류에 해당하는 'airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck'를 담는다.

# %%
# cifar10의 분류에 해당하는 'airplane', 'automobile', 'bird', 'cat', 'deer', 
# 'dog', 'frog', 'horse', 'ship', 'truck'를 class_name으로 정의합니다.
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

# %% [markdown]
# 데이터 중 샘플 하나를 시각화해보고, 데이터의 형태를 확인해본다.

# %%
# 훈련 데이터의 0번째인 x_train[0]를 이미지로 시각화합니다.
plt.style.use('seaborn-white')

plt.figure()
plt.imshow(x_train[0])
plt.colorbar()
plt.show()

# %%
# 훈련, 검증, 테스트 데이터의 형태(shape)을 출력합니다.
print(x_train.shape)
print(x_val.shape)
print(x_test.shape)
# Out:
# (40000, 32, 32, 3)
# (10000, 32, 32, 3)
# (10000, 32, 32, 3)

# %% [markdown]
# 데이터의 형태를 변형하여 모델이 잘 학습할 수 있게끔 해준다.

# %%
# 문제 3-2: 훈련, 검증, 테스트 데이터의 형태(shape)을 32 * 32 * 3 = 3072로 변형합니다.
x_train = x_train.reshape(-1, 3072)
x_val = x_val.reshape(-1, 3072)
x_test = x_test.reshape(-1, 3072)

print(x_train.shape)
print(x_val.shape)
print(x_test.shape)
# Out:
# (40000, 3072)
# (10000, 3072)
# (10000, 3072)

# %%
# 훈련, 검증, 테스트 데이터를 255로 나누어 0~1 사이의 값으로 변환합니다.
x_train = x_train / 255.
x_val = x_val / 255.
x_test = x_test / 255.

# %% [markdown]
# ## 모델 구성 및 컴파일

# %% [markdown]
# BatchNormalization과 Dropout을 적용하여 빠르게 학습하면서 과대적합을 방지하고, 10개의 이미지를 분류하는 딥러닝 모델을 구성합니다.

# %%
# 문제 3-3: BatchNormalization과 Dropout을 적용하여 빠른 학습과 과대적합을 방지하고,
# 10개의 이미지를 분류하는 딥러닝 모델을 구성합니다.
model = models.Sequential()

model.add(layers.Dense(2048, input_shape=(x_train.shape[1],)))
model.add(layers.BatchNormalization())
model.add(layers.Activation('relu'))
model.add(layers.Dropout(0.5))

model.add(layers.Dense(1024))
model.add(layers.BatchNormalization())
model.add(layers.Activation('relu'))
model.add(layers.Dropout(0.5))

model.add(layers.Dense(512))
model.add(layers.BatchNormalization())
model.add(layers.Activation('relu'))
model.add(layers.Dropout(0.5))

model.add(layers.Dense(10, activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 2048)              6293504
# _________________________________________________________________
# batch_normalization (BatchNo (None, 2048)              8192
# _________________________________________________________________
# activation (Activation)      (None, 2048)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              2098176
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 1024)              4096
# _________________________________________________________________
# activation_1 (Activation)    (None, 1024)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               524800
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 512)               2048
# _________________________________________________________________
# activation_2 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 8,935,946
# Trainable params: 8,928,778
# Non-trainable params: 7,168
# _________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model

plot_model(model, show_shapes=True)

# %% [markdown]
# ## 모델 학습

# %% [markdown]
# ModelCheckpoint와 EarlyStopping 콜백 함수를 적용하여 모델 학습을 진행한다.

# %%
from tensorflow.keras import callbacks

# 문제 3-4: ModelCheckpoint와 EarlyStopping 콜백 함수를 적용하여 모델 학습을 진행합니다.
check_point_cb = callbacks.ModelCheckpoint('keras_cifar10_model.h5', save_best_only=True)
early_stopping_cb = callbacks.EarlyStopping(patience=10, restore_best_weights=True)

model.compile(loss='sparse_categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

history = model.fit(x_train, y_train, epochs=50,
                    validation_data=(x_val, y_val),
                    callbacks=[check_point_cb, early_stopping_cb])
# Out:
# Epoch 1/50
# 1250/1250 [==============================] - 8s 5ms/step - loss: 1.9671 - accuracy: 0.3154 - val_loss: 1.7233 - val_accuracy: 0.3763
# Epoch 2/50
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.6692 - accuracy: 0.4039 - val_loss: 1.7525 - val_accuracy: 0.3789
# Epoch 3/50
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.5902 - accuracy: 0.4316 - val_loss: 1.6120 - val_accuracy: 0.4264
# Epoch 4/50
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.5398 - accuracy: 0.4514 - val_loss: 1.5439 - val_accuracy: 0.4447
# Epoch 5/50
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.4954 - accuracy: 0.4665 - val_loss: 1.6094 - val_accuracy: 0.4348
# Epoch 6/50
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.4625 - accuracy: 0.4798 - val_loss: 1.6320 - val_accuracy: 0.4125
# Epoch 7/50
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.4211 - accuracy: 0.4921 - val_loss: 1.4099 - val_accuracy: 0.4940
# Epoch 8/50
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.3960 - accuracy: 0.5012 - val_loss: 1.4329 - val_accuracy: 0.4897
# Epoch 9/50
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.3682 - accuracy: 0.5139 - val_loss: 1.4603 - val_accuracy: 0.4844
# Epoch 10/50
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.3469 - accuracy: 0.5222 - val_loss: 1.4318 - val_accuracy: 0.4874
# Epoch 11/50
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.3219 - accuracy: 0.5307 - val_loss: 1.4706 - val_accuracy: 0.4732
# Epoch 12/50
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.2940 - accuracy: 0.5401 - val_loss: 1.3994 - val_accuracy: 0.4980
# Epoch 13/50
# 1250/1250 [==============================] - 6s 4ms/step - loss: 1.2700 - accuracy: 0.5482 - val_loss: 1.5152 - val_accuracy: 0.4882
# Epoch 14/50
# 1250/1250 [==============================] - 6s 4ms/step - loss: 1.2586 - accuracy: 0.5524 - val_loss: 1.3377 - val_accuracy: 0.5216
# Epoch 15/50
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.2358 - accuracy: 0.5591 - val_loss: 1.3179 - val_accuracy: 0.5298
# Epoch 16/50
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.2124 - accuracy: 0.5701 - val_loss: 1.3176 - val_accuracy: 0.5358
# Epoch 17/50
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.1937 - accuracy: 0.5735 - val_loss: 1.4213 - val_accuracy: 0.4958
# Epoch 18/50
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.1787 - accuracy: 0.5800 - val_loss: 1.3334 - val_accuracy: 0.5310
# Epoch 19/50
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.1568 - accuracy: 0.5891 - val_loss: 1.2925 - val_accuracy: 0.5460
# Epoch 20/50
# 1250/1250 [==============================] - 6s 4ms/step - loss: 1.1428 - accuracy: 0.5957 - val_loss: 1.3419 - val_accuracy: 0.5286
# Epoch 21/50
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.1263 - accuracy: 0.6018 - val_loss: 1.6237 - val_accuracy: 0.4616
# Epoch 22/50
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.1011 - accuracy: 0.6075 - val_loss: 1.2771 - val_accuracy: 0.5449
# Epoch 23/50
# 1250/1250 [==============================] - 6s 4ms/step - loss: 1.0888 - accuracy: 0.6131 - val_loss: 1.2749 - val_accuracy: 0.5486
# Epoch 24/50
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.0761 - accuracy: 0.6160 - val_loss: 1.3568 - val_accuracy: 0.5368
# Epoch 25/50
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.0605 - accuracy: 0.6194 - val_loss: 1.3125 - val_accuracy: 0.5454
# Epoch 26/50
# 1250/1250 [==============================] - 6s 4ms/step - loss: 1.0455 - accuracy: 0.6274 - val_loss: 1.3400 - val_accuracy: 0.5332
# Epoch 27/50
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.0327 - accuracy: 0.6328 - val_loss: 1.3820 - val_accuracy: 0.5230
# Epoch 28/50
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.0124 - accuracy: 0.6397 - val_loss: 1.3635 - val_accuracy: 0.5331
# Epoch 29/50
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.0000 - accuracy: 0.6424 - val_loss: 1.4657 - val_accuracy: 0.5028
# Epoch 30/50
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.9898 - accuracy: 0.6459 - val_loss: 1.3800 - val_accuracy: 0.5306
# Epoch 31/50
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.9742 - accuracy: 0.6533 - val_loss: 1.5153 - val_accuracy: 0.5042
# Epoch 32/50
# 1250/1250 [==============================] - 6s 4ms/step - loss: 0.9616 - accuracy: 0.6582 - val_loss: 1.4085 - val_accuracy: 0.5365
# Epoch 33/50
# 1250/1250 [==============================] - 6s 4ms/step - loss: 0.9526 - accuracy: 0.6607 - val_loss: 1.3315 - val_accuracy: 0.5509

# %% [markdown]
# 학습 히스토리의 loss, val_loss, accuracy, val_accuracy를 차트로 시각화한다.

# %%
# 문제 3-5: 학습 히스토리의 `loss`, `val_loss`, `accuracy`, `val_accuracy`를 차트로 시각화합니다.
history_dict = history.history

loss = history_dict['loss']
val_loss = history_dict['val_loss']

epochs = range(1, len(loss) + 1)
fig = plt.figure(figsize=(12, 5))

ax1 = fig.add_subplot(1, 2, 1)
ax1.plot(epochs, loss, 'b-', label='train_loss')
ax1.plot(epochs, val_loss, 'r-', label='val_loss')
ax1.set_title('Train and Validation Loss')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss')
ax1.grid()
ax1.legend()

accuracy = history_dict['accuracy']
val_accuracy = history_dict['val_accuracy']

ax2 = fig.add_subplot(1, 2, 2)
ax2.plot(epochs, accuracy, 'b-', label='train_accuracy')
ax2.plot(epochs, val_accuracy, 'r-', label='val_accuracy')
ax2.set_title('Train and Validation Accuracy')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Accuracy')
ax2.grid()
ax2.legend()

plt.show()

# %% [markdown]
# ## 모델 평가 및 예측

# %% [markdown]
# 테스트 데이터셋을 이용해 모델을 평가한다.

# %%
# 테스트 데이터셋을 이용해 모델을 평가합니다.
model.evaluate(x_test, y_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 1.2699 - accuracy: 0.5518
# [1.2698843479156494, 0.551800012588501]
